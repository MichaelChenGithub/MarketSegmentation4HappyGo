# %%
from IPython.display import display
import pandas as pd
import glob
# change file path if your files not in the same folder
txt_files = glob.glob("../sample/*.txt")
df_list = []
for i in txt_files:
    df_name = i.split('.')[0]
    df_list.append(df_name)
    globals()[f"{df_name}"] = pd.read_csv(i)
    print(f'{df_name}')
    display(pd.read_csv(i))
# Out:
#         uid    start_dt      start_tm             event_id event_desc  \
# 0   2878774  2021/01/01  00:10:26.204  GM_2_HighlightGame6       點點推薦
# 1   2878774  2021/01/01  00:10:36.830  GM_2_HighlightGame1       點點推薦
# 2   2878774  2021/01/01  00:10:42.312  GM_2_HighlightGame2       點點推薦
# 3   2878774  2021/01/01  00:10:59.403  GM_2_HighlightGame2       點點推薦
# 4    519231  2021/01/01  00:15:58.030           MA_2_Game3         任務
# ..      ...         ...           ...                  ...        ...
# 95  3826329  2021/01/01  00:02:20.220  GM_2_HighlightGame4       點點推薦
# 96  5567179  2021/01/01  00:02:23.204           MA_2_Game1         任務
# 97  1359986  2021/01/01  00:02:23.383           MA_2_Game6         任務
# 98  7186881  2021/01/01  00:02:23.124           MA_2_Game1         任務
# 99  4166858  2021/01/01  00:02:24.396           MA_2_Game1         任務
#
#    shrcut_desc              game_id bnnr_id
# 0            ?  1606389688613001000       ?
# ...
